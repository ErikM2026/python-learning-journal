# %%
#3 items

def item_total(price, quantity):
  new_item_total = price * quantity
  return print(f"The item total is {(new_item_total):.2f}")

def calculate_subtotal(samount1, samount2, samount3):
  amounts = [amount1, amount2, amount3]
  new_subtotal1 = sum(amounts)
  return print(f"The subtotal is {(new_subtotal1):.2f}")

def calculate_discount(subtotal, discount_percent):
  new_discount = (subtotal * discount_percent) / 100
  return print(f"The discount % in dollars is ${(new_discount):.2f}")

def calculate_final_total(subtotal, discount_amount):
  new_final_total = subtotal - discount_amount
  return print(f"The final total is ${(new_final_total):.2f}")


store_name = input("What is the store name? ")
print(""+store_name+" online service is now active: ")


product1 = input("What is the name of the 1st thing that you're buying? ")


price1 = float(input("What is the price of the "+product1+"? "))
quantity1 = int(input("How many are you buying? "))
amount1 = price1 * quantity1

item_total(price1, quantity1)

product2 = input("What is the name of the 2nd thing that you're buying? ")

price2 = float(input("What is the price of the "+product2+"? "))
quantity2 = int(input("How many are you buying? "))
amount2 = price2 * quantity2

item_total(price2, quantity2)

product3 = input("What is the name of the 3rd thing that you're buying? ")

price3 = float(input("What is the price of the "+product3+"? "))
quantity3 = int(input("How many are you buying? "))
amount3 = price3 * quantity3

item_total(price3, quantity3)




calculate_subtotal(amount1, amount2, amount3)
amounts = [amount1, amount2, amount3]
new_subtotal1 = sum(amounts)

discount1 = float(input("What is the discount %? "))
calculate_discount(new_subtotal1, discount1)

new_discount = (new_subtotal1 * discount1) / 100
calculate_final_total(new_subtotal1, new_discount)

print("Thank you for shopping at "+store_name+"!")
# Out:
# What is the store name? Walmart
# Walmart online service is now active:
# What is the name of the 1st thing that you're buying? TV
# What is the price of the TV? 3.50
# How many are you buying? 2
# The item total is 7.00
# What is the name of the 2nd thing that you're buying? Shoes
# What is the price of the Shoes? 2.00
# How many are you buying? 3
# The item total is 6.00
# What is the name of the 3rd thing that you're buying? Shirts
# What is the price of the Shirts? 12.00
# How many are you buying? 1
# The item total is 12.00
# The subtotal is 25.00
# What is the discount %? 10
# The discount % in dollars is $2.50
# The final total is $22.50
# Thank you for shopping at Walmart!
